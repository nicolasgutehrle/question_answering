# %%
# downdload the SQuAD dataset
# !mkdir ../datasets/SQuAD
# !wget -P ../datasets/SQuAD https://rajpurkar.github.io/SQuAD-explorer/dataset/train-v2.0.json
# !wget -P ../datasets/SQuAD https://rajpurkar.github.io/SQuAD-explorer/dataset/dev-v2.0.json
# !wget -P ../datasets/SQuAD https://worksheets.codalab.org/rest/bundles/0x6b567e1cf2e041ec80d7098f031c5c9e/contents/blob/
# !wget -P ../datasets/SQuAD https://worksheets.codalab.org/bundles/0x8731effab84f41b7b874a070e40f61e2/
# Out:
# --2020-03-17 17:46:50--  https://rajpurkar.github.io/SQuAD-explorer/dataset/train-v2.0.json
# Resolving rajpurkar.github.io (rajpurkar.github.io)... 185.199.110.153, 185.199.111.153, 185.199.108.153, ...
# Connecting to rajpurkar.github.io (rajpurkar.github.io)|185.199.110.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 42123633 (40M) [application/json]
# Saving to: ‘/storage/SQuAD/train-v2.0.json’
#
# train-v2.0.json     100%[===================>]  40.17M  72.7MB/s    in 0.6s
#
# 2020-03-17 17:46:52 (72.7 MB/s) - ‘/storage/SQuAD/train-v2.0.json’ saved [42123633/42123633]
#
# --2020-03-17 17:46:52--  https://rajpurkar.github.io/SQuAD-explorer/dataset/dev-v2.0.json
# Resolving rajpurkar.github.io (rajpurkar.github.io)... 185.199.110.153, 185.199.111.153, 185.199.108.153, ...
# Connecting to rajpurkar.github.io (rajpurkar.github.io)|185.199.110.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# ...

# %%
# !git clone https://github.com/huggingface/transformers.git
# Out:
# fatal: destination path 'transformers' already exists and is not an empty directory.

# %%
cd transformers/
# Out:
# /storage/transformers

# %%
# !pip install .
# Out:
# Processing /storage/transformers
# ...
#   Created wheel for transformers: filename=transformers-2.5.1-cp36-none-any.whl size=533120 sha256=481ab9dd78857dd724b131c092d0285cbfc53787bedc8593ff5666d16693f4f8
#   Stored in directory: /tmp/pip-ephem-wheel-cache-764nxtyq/wheels/a0/63/29/3db641914b691df45269aa96f7b04959dc9c0e238e3cc605ef
# Successfully built transformers
# ...
#   Found existing installation: transformers 2.5.1
#     Uninstalling transformers-2.5.1:
#       Successfully uninstalled transformers-2.5.1
# ...
# WARNING: You are using pip version 19.2.1, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
cd examples/
# Out:
# /storage/transformers/examples

# %%
# exporting the location of the dataset in the ENV path
import os
os.environ['SQUAD_DIR'] = "../datasets/SQuAD"
# !echo $SQUAD_DIR
# Out:
# /storage/SQuAD

# %%
# command line parameters and run the script
run_squad_command = """
python run_squad.py
--model_type bert
--model_name_or_path bert-base-uncased
--do_train
--do_eval
--do_lower_case
--train_file $SQUAD_DIR/train-v2.0.json
--predict_file $SQUAD_DIR/dev-v2.0.json
--per_gpu_train_batch_size 12
--learning_rate 3e-5
--num_train_epochs 2.0
--max_seq_length 384
--doc_stride 128
--output_dir ../models/en/17032020/
--version_2_with_negative"""
run_squad_command = run_squad_command.replace("\n", " ")

# %%
# !{run_squad_command}
# Out:
# 03/18/2020 07:04:52 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 03/18/2020 07:04:52 - INFO - transformers.configuration_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.8f56353af4a709bf5ff0fbc915d8f5b42bfff892cbb6ac98c3c45f481a03c685
# 03/18/2020 07:04:52 - INFO - transformers.configuration_utils -   Model config BertConfig {
#   "_num_labels": 2,
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": null,
#   "do_sample": false,
#   "early_stopping": false,
#   "eos_token_ids": null,
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1"
#   },
# ...
